# %% [markdown]
# <a href="https://colab.research.google.com/github/Alenushka2013/ML_for_people_tasks/blob/main/hw_3_4_apply%2C_groupby%2C_pivot_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('drive/MyDrive/DataLove_ML/Data/supermarket_sales.csv')

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].sum().idxmax()
# Out:
# 'C'

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
best_branch = df.groupby('Branch')['gross income'].sum().idxmax()
print(*df.City[df.Branch == best_branch].unique())
# Out:
# Naypyitaw

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
invoices_by_category = df.pivot_table(index = 'Branch', columns = 'Product line', values='Invoice ID', aggfunc='count')

# %%
invoices_by_category
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
res = invoices_by_category[invoices_by_category['Electronic accessories'] == invoices_by_category['Electronic accessories'].max()]

# %%
print(*res.index)
# Out:
# A

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# 1.Скільки коштів витрачають клієнти в залежності від типу клієнта та статі

# %%
df.groupby(['Branch', 'Gender', 'Customer type']).Total.sum()
# Out:
# Branch  Gender  Customer type
# A       Female  Member           26643.0675
#                 Normal           26626.0995
#         Male    Member           26994.4080
#                 Normal           25936.7955
# B       Female  Member           26850.4320
#                 Normal           26077.8630
#         Male    Member           26854.2540
#                 Normal           26415.1230
# C       Female  Member           34653.4440
#                 Normal           27032.0190
#         Male    Member           22227.8385
#                 Normal           26655.4050
# Name: Total, dtype: float64

# %%
df.groupby(["Gender", "Customer type"])["gross income"].mean().unstack()
# Out:
# Customer type     Member     Normal
# Gender
# Female         16.082274  15.820631
# Male           15.094544  14.526075

# %% [markdown]
# В цілому жінки дають більше прибутку мережі супермаркетів. А в філіалі С це жінки, які є постійними покупцями.

# %% [markdown]
# 2. Який спосіб розрахунку клієнтами в зележності від членства приносить більше прибутку супермаркетам

# %%
df.pivot_table(index = 'Customer type', columns = 'Payment', values='gross income', aggfunc='sum')
# Out:
# Payment             Cash  Credit card   Ewallet
# Customer type
# Member         2602.9055    2751.0225  2466.236
# Normal         2740.2645    2047.4095  2771.531

# %% [markdown]
# Найменший прибуток для нових клієнтів, які розраховуються кредитними картками, отже потрібно щоб були доступні і зручні альтернативні форми розрахунку.

# %% [markdown]
# 3. Як змінився рівень прибутку для кожного магазину за 3 місяці та які категорії товарів цьому сприяли.

# %%
# Створення стовбчика з місяцем покупки
df["Date_month"] = pd.to_datetime(df["Date"]).dt.month

# %%
# Середній дохід по кожній філії і місяцю покупки
df.groupby(['Branch', 'Date_month'])['gross income'].mean()
# Out:
# Branch  Date_month
# A       1             15.478643
#         2             15.126707
#         3             14.120406
# B       1             15.948545
#         2             15.039000
#         3             14.709754
# C       1             15.782467
#         2             15.683325
#         3             16.711160
# Name: gross income, dtype: float64

# %%
# Середній дохід по кожній філії, категорії товару і місяцю покупки
df.groupby(["Branch",  "Product line", 'Date_month'])["gross income"].mean()
# Out:
# Branch  Product line            Date_month
# A       Electronic accessories  1             14.515357
#                                 2             13.763944
#                                 3             15.222381
#         Fashion accessories     1             16.303550
#                                 2             15.397719
#                                 3             13.686933
#         Food and beverages      1             14.749933
#                                 2             15.995976
#                                 3             11.823909
#         Health and beauty       1             15.724583
#                                 2             11.569375
#                                 3             11.841978
#         Home and lifestyle      1             18.189759
#                                 2             17.478500
#                                 3             13.965660
#         Sports and travel       1             12.916562
# ...

# %% [markdown]
# **Спостереження**:
# - у філіях А та В відмічається  зміншення доходу з часом
# - для філії С відмічається зростання
# - для філії А прибутки зростають у категоріях: Electronic accessories, Sports and travel
# - для філії В прибутки зростають у категоріях: Home and lifestyle, Sports and travel
# - для філії С прибутки зростають у категоріях: Food and beverages, Health and beauty, Home and lifestyle

# %% [markdown]
# **Бізнес-рекомендації:**
#
# - відкривати новий супермаркет варто там, де розташована філія С
#
# - зробити більш різноманітним асортимент товарів тих категорій, які користуються найбільшим попитом у даному місті
#
# - запустити рекламу для найприбутковіших груп клієнтів та зробити покупки та асортимент привабливішим для жінок, оскільки вони витрачають більше
#
# - просувати методи оплати, пов’язані з більшими витратами.
