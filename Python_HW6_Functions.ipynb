# %% [markdown]
# <a href="https://colab.research.google.com/github/Alenushka2013/ML_for_people_tasks/blob/main/Python_HW6_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Функція з параметром**
#
# Створіть функцію `show_menu()`, яка приймає перелік страв, наприклад ['Піца', 'Паста', 'Салат'] і виводить меню ресторану в наступному вигляді:
# ```
# === МЕНЮ ===
# 1. Піца
# 2. Паста
# 3. Салат
# =============
# ```
#
# Викличте цю функцію на списку ["Суп грибний", "Котлета по-київськи", "Лимонад"].

# %%
def show_menu(list_of_dishes):
  print('=== МЕНЮ ===')
  for index, dish in enumerate(list_of_dishes):
    print(f'{index + 1}. {dish}')
  print('='*12)

# %%
show_menu(["Суп грибний", "Котлета по-київськи", "Лимонад"])
# Out:
# === МЕНЮ ===
# 1. Суп грибний
# 2. Котлета по-київськи
# 3. Лимонад
# ============

# %% [markdown]
# ---
#
# **2. Функція з параметром**
#
# Створіть функцію `print_square(n)`, яка виводить квадрат числа.
#
# Наприклад: `print_square(5)` → "Квадрат числа 5 = 25"
#
# Викличте її з різними числами.

# %%
def print_square(n):
  print(f"Квадрат числа {n} = {n ** 2}")

# %%
print_square(1.5)
print_square(-3)
print_square(16)
# Out:
# Квадрат числа 1.5 = 2.25
# Квадрат числа -3 = 9
# Квадрат числа 16 = 256

# %% [markdown]
# ---
#
# **3. Функція з поверненням значення**
#
# Створіть функцію `multiply(a, b)`, яка повертає добуток двох чисел.
#
# Викличте функцію на власноруч заданих значеннях та виведіть результат.

# %%
def multiply(a, b):
  return a * b

# %%
a = [1, 3, 7, -4, 17]
b = [-5, 9, 0, 11, -1]

for i in range(len(a)):
  print(f'добуток чисел {a[i]} і {b[i]} = {multiply(a[i], b[i])}')
# Out:
# добуток чисел 1 і -5 = -5
# добуток чисел 3 і 9 = 27
# добуток чисел 7 і 0 = 0
# добуток чисел -4 і 11 = -44
# добуток чисел 17 і -1 = -17

# %% [markdown]
# ---
#
# **4. Функція пошуку максимумального значення**
#
# Створіть функцію `find_max(numbers)`, яка:
# - Приймає список чисел
# - Повертає найбільше число в списку
#
# Протестуйте на списку `[15, 42, 8, 23, 56, 19]`.

# %%
def find_max(numbers):
  return max(numbers)

numbers = [15, 42, 8, 23, 56, 19]

print(f'найбільше число в списку {find_max(numbers)}')
# Out:
# найбільше число в списку 56

# %% [markdown]
# ---
#
# **5. Функція з умовами**
#
# Створіть функцію `check_grade(grade)`, яка:
# - Приймає оцінку (число)
# - Повертає "Здав" якщо grade >= 60
# - Повертає "Не здав" якщо grade < 60
#
# Протестуйте на різних оцінках.

# %%
def check_grade(grade):
  return "Здав" if grade >= 60 else "Не здав"

grades = [99, 54, 78, 11, 60]
for grade in grades:
  print(f'Якщо оцінка {grade}, результат: {check_grade(grade)}')
# Out:
# Якщо оцінка 99, результат: Здав
# Якщо оцінка 54, результат: Не здав
# Якщо оцінка 78, результат: Здав
# Якщо оцінка 11, результат: Не здав
# Якщо оцінка 60, результат: Здав
